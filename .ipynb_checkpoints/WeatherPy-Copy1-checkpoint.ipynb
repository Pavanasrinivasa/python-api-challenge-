# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import os
import json
import random
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from ratelimit import limits
# Import API key
from api_keys import weather_api_key
from api_keys import g_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 614

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?"
# Counter to go through data
record = 0
sets = 1
# Create DataFrame
weather_df = pd.DataFrame({"City": cities})
weather_df["Cloudiness"] = ""
weather_df["Country"] = ""
weather_df["Date"] = ""
weather_df["Humidity"] = ""
weather_df["Latitude"] = ""
weather_df["Longitude"] = ""
weather_df["Max Temp"] = ""
weather_df["Wind Speed"] = ""
# Interate through Cities and retrieve data
print("Beginning Data Retrieval")
print("-----------------------------")
for index, row in weather_df.iterrows():
 city = row["City"]
 query_url = base_url + "appid=" + weather_api_key + "&q=" + city
 weather_response = requests.get(query_url).json()
 try:
     print(f"Processing Record {record}  of Set {sets} | {city}.")
     #print (query_url)
     weather_df.loc[index, "Cloudiness"] = weather_response["clouds"]["all"]
     weather_df.loc[index, "Country"] = weather_response["sys"]["country"]
     weather_df.loc[index, "Date"] = weather_response["dt"]
     weather_df.loc[index, "Humidity"] = weather_response["main"]["humidity"]
     weather_df.loc[index, "Latitude"] = weather_response["coord"]["lat"]
     weather_df.loc[index, "Longitude"] = weather_response["coord"]["lon"]
     weather_df.loc[index, "Max Temp"] = weather_response["main"]["temp_max"]
     weather_df.loc[index, "Wind Speed"] = weather_response["wind"]["speed"]
 except:
     print("City not found...skipping.")
     #print (query_url)
     weather_df.loc[index, "Cloudiness"] = ""
     weather_df.loc[index, "Country"] = ""
     weather_df.loc[index, "Date"] = ""
     weather_df.loc[index, "Humidity"] = ""
     weather_df.loc[index, "Latitude"] = ""
     weather_df.loc[index, "Longitude"] = ""
     weather_df.loc[index, "Max Temp"] = ""
     weather_df.loc[index, "Wind Speed"] = ""
 record = record + 1
 if record == 50:
     record = 0
     sets = sets + 1
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0  of Set 1 | monster.
# Processing Record 1  of Set 1 | kapaa.
# Processing Record 2  of Set 1 | tilichiki.
# Processing Record 3  of Set 1 | upernavik.
# Processing Record 4  of Set 1 | conde.
# Processing Record 5  of Set 1 | barrow.
# Processing Record 6  of Set 1 | cape town.
# Processing Record 7  of Set 1 | saint-philippe.
# Processing Record 8  of Set 1 | ushuaia.
# Processing Record 9  of Set 1 | atuona.
# Processing Record 10  of Set 1 | souillac.
# Processing Record 11  of Set 1 | talnakh.
# Processing Record 12  of Set 1 | severo-kurilsk.
# Processing Record 13  of Set 1 | brae.
# Processing Record 14  of Set 1 | kirakira.
# Processing Record 15  of Set 1 | lohja.
# Processing Record 16  of Set 1 | illoqqortoormiut.
# City not found...skipping.
# Processing Record 17  of Set 1 | kerema.
# Processing Record 18  of Set 1 | samalaeulu.
# City not found...skipping.
# Processing Record 19  of Set 1 | taolanaro.
# City not found...skipping.
# Processing Record 20  of Set 1 | eureka.
# Processing Record 21  of Set 1 | albany.
# Processing Record 22  of Set 1 | la ronge.
# Processing Record 23  of Set 1 | norman wells.
# Processing Record 24  of Set 1 | kodiak.
# Processing Record 25  of Set 1 | neuquen.
# Processing Record 26  of Set 1 | porciuncula.
# Processing Record 27  of Set 1 | bambanglipuro.
# Processing Record 28  of Set 1 | chokurdakh.
# Processing Record 29  of Set 1 | najran.
# Processing Record 30  of Set 1 | rikitea.
# Processing Record 31  of Set 1 | chuy.
# Processing Record 32  of Set 1 | richards bay.
# Processing Record 33  of Set 1 | los llanos de aridane.
# Processing Record 34  of Set 1 | husavik.
# Processing Record 35  of Set 1 | vardo.
# Processing Record 36  of Set 1 | bonavista.
# Processing Record 37  of Set 1 | torbay.
# Processing Record 38  of Set 1 | arraial do cabo.
# Processing Record 39  of Set 1 | barentsburg.
# City not found...skipping.
# Processing Record 40  of Set 1 | ulaangom.
# Processing Record 41  of Set 1 | yellowknife.
# Processing Record 42  of Set 1 | boa vista.
# Processing Record 43  of Set 1 | volodarka.
# Processing Record 44  of Set 1 | saskylakh.
# Processing Record 45  of Set 1 | ussel.
# Processing Record 46  of Set 1 | fort nelson.
# Processing Record 47  of Set 1 | mys shmidta.
# City not found...skipping.
# Processing Record 48  of Set 1 | mataura.
# Processing Record 49  of Set 1 | kavieng.
# Processing Record 0  of Set 2 | pevek.
# Processing Record 1  of Set 2 | amta.
# Processing Record 2  of Set 2 | moissala.
# Processing Record 3  of Set 2 | barcelos.
# Processing Record 4  of Set 2 | puerto ayora.
# Processing Record 5  of Set 2 | busselton.
# Processing Record 6  of Set 2 | barawe.
# City not found...skipping.
# Processing Record 7  of Set 2 | kulunda.
# Processing Record 8  of Set 2 | punta arenas.
# Processing Record 9  of Set 2 | qaanaaq.
# Processing Record 10  of Set 2 | dikson.
# Processing Record 11  of Set 2 | todos santos.
# Processing Record 12  of Set 2 | thompson.
# Processing Record 13  of Set 2 | bouar.
# Processing Record 14  of Set 2 | bambous virieux.
# Processing Record 15  of Set 2 | port alfred.
# Processing Record 16  of Set 2 | bredasdorp.
# Processing Record 17  of Set 2 | samarai.
# Processing Record 18  of Set 2 | hovd.
# Processing Record 19  of Set 2 | hilo.
# Processing Record 20  of Set 2 | mbala.
# Processing Record 21  of Set 2 | nome.
# Processing Record 22  of Set 2 | krasne.
# Processing Record 23  of Set 2 | kamenka.
# Processing Record 24  of Set 2 | vicuna.
# City not found...skipping.
# Processing Record 25  of Set 2 | ponta delgada.
# Processing Record 26  of Set 2 | necochea.
# Processing Record 27  of Set 2 | sentyabrskiy.
# City not found...skipping.
# Processing Record 28  of Set 2 | grand river south east.
# City not found...skipping.
# Processing Record 29  of Set 2 | dunedin.
# Processing Record 30  of Set 2 | jamestown.
# Processing Record 31  of Set 2 | genhe.
# Processing Record 32  of Set 2 | charlestown.
# Processing Record 33  of Set 2 | san quintin.
# Processing Record 34  of Set 2 | lebu.
# Processing Record 35  of Set 2 | hermanus.
# Processing Record 36  of Set 2 | whitley bay.
# Processing Record 37  of Set 2 | rawson.
# Processing Record 38  of Set 2 | tyup.
# Processing Record 39  of Set 2 | vaini.
# Processing Record 40  of Set 2 | airai.
# Processing Record 41  of Set 2 | faanui.
# Processing Record 42  of Set 2 | deputatskiy.
# Processing Record 43  of Set 2 | basyanovskiy.
# City not found...skipping.
# Processing Record 44  of Set 2 | bathsheba.
# Processing Record 45  of Set 2 | grand centre.
# City not found...skipping.
# Processing Record 46  of Set 2 | bethel.
# Processing Record 47  of Set 2 | westport.
# Processing Record 48  of Set 2 | bushehr.
# Processing Record 49  of Set 2 | butembo.
# Processing Record 0  of Set 3 | port elizabeth.
# Processing Record 1  of Set 3 | palafrugell.
# Processing Record 2  of Set 3 | yenagoa.
# Processing Record 3  of Set 3 | kotdwara.
# Processing Record 4  of Set 3 | carnarvon.
# Processing Record 5  of Set 3 | morros.
# Processing Record 6  of Set 3 | bubaque.
# Processing Record 7  of Set 3 | klaksvik.
# Processing Record 8  of Set 3 | bonthe.
# Processing Record 9  of Set 3 | maceio.
# Processing Record 10  of Set 3 | tucuma.
# City not found...skipping.
# Processing Record 11  of Set 3 | tasiilaq.
# Processing Record 12  of Set 3 | buraydah.
# Processing Record 13  of Set 3 | bluff.
# Processing Record 14  of Set 3 | aiken.
# Processing Record 15  of Set 3 | lydenburg.
# Processing Record 16  of Set 3 | dingle.
# Processing Record 17  of Set 3 | galveston.
# Processing Record 18  of Set 3 | sawtell.
# Processing Record 19  of Set 3 | zhovtneve.
# City not found...skipping.
# Processing Record 20  of Set 3 | nampula.
# Processing Record 21  of Set 3 | barbar.
# City not found...skipping.
# Processing Record 22  of Set 3 | aykhal.
# Processing Record 23  of Set 3 | khatanga.
# Processing Record 24  of Set 3 | tuatapere.
# Processing Record 25  of Set 3 | leningradskiy.
# Processing Record 26  of Set 3 | komsomolskiy.
# Processing Record 27  of Set 3 | ilulissat.
# Processing Record 28  of Set 3 | karratha.
# Processing Record 29  of Set 3 | faya.
# Processing Record 30  of Set 3 | domoni.
# City not found...skipping.
# Processing Record 31  of Set 3 | padang.
# Processing Record 32  of Set 3 | broome.
# Processing Record 33  of Set 3 | dzhusaly.
# City not found...skipping.
# Processing Record 34  of Set 3 | olafsvik.
# City not found...skipping.
# Processing Record 35  of Set 3 | butaritari.
# Processing Record 36  of Set 3 | stantsiya gorchakovo.
# City not found...skipping.
# Processing Record 37  of Set 3 | ancud.
# Processing Record 38  of Set 3 | pokhara.
# Processing Record 39  of Set 3 | lasa.
# Processing Record 40  of Set 3 | nouadhibou.
# Processing Record 41  of Set 3 | castro.
# Processing Record 42  of Set 3 | avarua.
# Processing Record 43  of Set 3 | port blair.
# Processing Record 44  of Set 3 | umzimvubu.
# City not found...skipping.
# Processing Record 45  of Set 3 | nizhneyansk.
# City not found...skipping.
# Processing Record 46  of Set 3 | uyuni.
# Processing Record 47  of Set 3 | hambantota.
# Processing Record 48  of Set 3 | hofn.
# Processing Record 49  of Set 3 | east london.
# Processing Record 0  of Set 4 | mbekenyera.
# Processing Record 1  of Set 4 | lagoa.
# Processing Record 2  of Set 4 | davenda.
# Processing Record 3  of Set 4 | kaitangata.
# Processing Record 4  of Set 4 | skjervoy.
# Processing Record 5  of Set 4 | payson.
# Processing Record 6  of Set 4 | hualmay.
# Processing Record 7  of Set 4 | pingzhuang.
# City not found...skipping.
# Processing Record 8  of Set 4 | mar del plata.
# Processing Record 9  of Set 4 | inuvik.
# Processing Record 10  of Set 4 | nouakchott.
# Processing Record 11  of Set 4 | taltal.
# Processing Record 12  of Set 4 | cabo san lucas.
# Processing Record 13  of Set 4 | porbandar.
# Processing Record 14  of Set 4 | el faiyum.
# City not found...skipping.
# Processing Record 15  of Set 4 | marcona.
# City not found...skipping.
# Processing Record 16  of Set 4 | piripiri.
# Processing Record 17  of Set 4 | englewood.
# Processing Record 18  of Set 4 | cururupu.
# Processing Record 19  of Set 4 | horki.
# Processing Record 20  of Set 4 | ambilobe.
# Processing Record 21  of Set 4 | magadan.
# Processing Record 22  of Set 4 | provideniya.
# Processing Record 23  of Set 4 | atar.
# Processing Record 24  of Set 4 | port lincoln.
# Processing Record 25  of Set 4 | logan lake.
# Processing Record 26  of Set 4 | hithadhoo.
# Processing Record 27  of Set 4 | opunake.
# Processing Record 28  of Set 4 | yarmouth.
# Processing Record 29  of Set 4 | esso.
# Processing Record 30  of Set 4 | saint-joseph.
# Processing Record 31  of Set 4 | mahebourg.
# Processing Record 32  of Set 4 | kathu.
# Processing Record 33  of Set 4 | katsuura.
# Processing Record 34  of Set 4 | attawapiskat.
# City not found...skipping.
# Processing Record 35  of Set 4 | seymchan.
# Processing Record 36  of Set 4 | marzuq.
# Processing Record 37  of Set 4 | keningau.
# Processing Record 38  of Set 4 | hasaki.
# Processing Record 39  of Set 4 | mullaitivu.
# City not found...skipping.
# Processing Record 40  of Set 4 | rochefort.
# Processing Record 41  of Set 4 | victoria.
# Processing Record 42  of Set 4 | pemberton.
# Processing Record 43  of Set 4 | roma.
# Processing Record 44  of Set 4 | gazli.
# Processing Record 45  of Set 4 | luderitz.
# Processing Record 46  of Set 4 | whitehorse.
# Processing Record 47  of Set 4 | san patricio.
# Processing Record 48  of Set 4 | new norfolk.
# Processing Record 49  of Set 4 | filadelfia.
# Processing Record 0  of Set 5 | vaitape.
# Processing Record 1  of Set 5 | touros.
# Processing Record 2  of Set 5 | ikirun.
# Processing Record 3  of Set 5 | emerald.
# Processing Record 4  of Set 5 | praia da vitoria.
# Processing Record 5  of Set 5 | iwanai.
# Processing Record 6  of Set 5 | port hardy.
# Processing Record 7  of Set 5 | bria.
# Processing Record 8  of Set 5 | nanakuli.
# Processing Record 9  of Set 5 | araouane.
# Processing Record 10  of Set 5 | sao filipe.
# Processing Record 11  of Set 5 | busembatia.
# Processing Record 12  of Set 5 | hobart.
# Processing Record 13  of Set 5 | andenes.
# City not found...skipping.
# Processing Record 14  of Set 5 | lincoln.
# Processing Record 15  of Set 5 | simbahan.
# Processing Record 16  of Set 5 | saint-augustin.
# Processing Record 17  of Set 5 | half moon bay.
# Processing Record 18  of Set 5 | ixtapa.
# Processing Record 19  of Set 5 | tiksi.
# Processing Record 20  of Set 5 | belushya guba.
# City not found...skipping.
# Processing Record 21  of Set 5 | portland.
# Processing Record 22  of Set 5 | geresk.
# City not found...skipping.
# Processing Record 23  of Set 5 | leh.
# Processing Record 24  of Set 5 | malwan.
# City not found...skipping.
# Processing Record 25  of Set 5 | koutsouras.
# Processing Record 26  of Set 5 | reefton.
# City not found...skipping.
# Processing Record 27  of Set 5 | kamenskoye.
# City not found...skipping.
# Processing Record 28  of Set 5 | sitka.
# Processing Record 29  of Set 5 | ambon.
# Processing Record 30  of Set 5 | codrington.
# Processing Record 31  of Set 5 | clyde river.
# Processing Record 32  of Set 5 | longyearbyen.
# Processing Record 33  of Set 5 | baherden.
# Processing Record 34  of Set 5 | tulum.
# Processing Record 35  of Set 5 | udachnyy.
# Processing Record 36  of Set 5 | nago.
# Processing Record 37  of Set 5 | mareeba.
# Processing Record 38  of Set 5 | kamaishi.
# Processing Record 39  of Set 5 | moose factory.
# Processing Record 40  of Set 5 | oum hadjer.
# Processing Record 41  of Set 5 | fuerte olimpo.
# Processing Record 42  of Set 5 | saint george.
# Processing Record 43  of Set 5 | lorengau.
# Processing Record 44  of Set 5 | cap malheureux.
# Processing Record 45  of Set 5 | nelson bay.
# Processing Record 46  of Set 5 | meyungs.
# City not found...skipping.
# Processing Record 47  of Set 5 | tuktoyaktuk.
# Processing Record 48  of Set 5 | urucui.
# Processing Record 49  of Set 5 | port victoria.
# Processing Record 0  of Set 6 | georgetown.
# Processing Record 1  of Set 6 | formoso do araguaia.
# City not found...skipping.
# Processing Record 2  of Set 6 | kavaratti.
# Processing Record 3  of Set 6 | amderma.
# City not found...skipping.
# Processing Record 4  of Set 6 | sapao.
# City not found...skipping.
# Processing Record 5  of Set 6 | cherskiy.
# Processing Record 6  of Set 6 | lyubech.
# Processing Record 7  of Set 6 | isangel.
# Processing Record 8  of Set 6 | balkanabat.
# Processing Record 9  of Set 6 | abu jubayhah.
# City not found...skipping.
# Processing Record 10  of Set 6 | vaitupu.
# City not found...skipping.
# Processing Record 11  of Set 6 | kasongo.
# Processing Record 12  of Set 6 | piacabucu.
# Processing Record 13  of Set 6 | nantucket.
# Processing Record 14  of Set 6 | qingdao.
# Processing Record 15  of Set 6 | broken hill.
# Processing Record 16  of Set 6 | te anau.
# Processing Record 17  of Set 6 | weymouth.
# Processing Record 18  of Set 6 | rumphi.
# Processing Record 19  of Set 6 | shingu.
# Processing Record 20  of Set 6 | tahe.
# Processing Record 21  of Set 6 | gazalkent.
# Processing Record 22  of Set 6 | baykit.
# Processing Record 23  of Set 6 | devils lake.
# Processing Record 24  of Set 6 | rungata.
# City not found...skipping.
# Processing Record 25  of Set 6 | barkly west.
# Processing Record 26  of Set 6 | kalisz.
# Processing Record 27  of Set 6 | narsaq.
# Processing Record 28  of Set 6 | antofagasta.
# Processing Record 29  of Set 6 | buchanan.
# Processing Record 30  of Set 6 | marathopolis.
# City not found...skipping.
# Processing Record 31  of Set 6 | hami.
# Processing Record 32  of Set 6 | kozluk.
# Processing Record 33  of Set 6 | krasnoselkup.
# City not found...skipping.
# Processing Record 34  of Set 6 | maniitsoq.
# Processing Record 35  of Set 6 | louisbourg.
# City not found...skipping.
# Processing Record 36  of Set 6 | makakilo city.
# Processing Record 37  of Set 6 | ribeira grande.
# Processing Record 38  of Set 6 | iranshahr.
# Processing Record 39  of Set 6 | tocache.
# Processing Record 40  of Set 6 | kashan.
# Processing Record 41  of Set 6 | saint-pierre.
# Processing Record 42  of Set 6 | macomb.
# Processing Record 43  of Set 6 | ulladulla.
# Processing Record 44  of Set 6 | fort saint james.
# Processing Record 45  of Set 6 | samusu.
# City not found...skipping.
# Processing Record 46  of Set 6 | vanavara.
# Processing Record 47  of Set 6 | lephepe.
# City not found...skipping.
# Processing Record 48  of Set 6 | riyadh.
# Processing Record 49  of Set 6 | nenjiang.
# Processing Record 0  of Set 7 | sao joao da barra.
# Processing Record 1  of Set 7 | sistranda.
# Processing Record 2  of Set 7 | sabang.
# Processing Record 3  of Set 7 | lhuntshi.
# City not found...skipping.
# Processing Record 4  of Set 7 | salalah.
# Processing Record 5  of Set 7 | pangody.
# Processing Record 6  of Set 7 | dwarka.
# Processing Record 7  of Set 7 | nikolskoye.
# Processing Record 8  of Set 7 | buenos aires.
# Processing Record 9  of Set 7 | zhongshu.
# Processing Record 10  of Set 7 | lora del rio.
# Processing Record 11  of Set 7 | beira.
# Processing Record 12  of Set 7 | cidreira.
# Processing Record 13  of Set 7 | sarai.
# Processing Record 14  of Set 7 | marietta.
# Processing Record 15  of Set 7 | shihezi.
# Processing Record 16  of Set 7 | naryan-mar.
# Processing Record 17  of Set 7 | yar-sale.
# Processing Record 18  of Set 7 | lavrentiya.
# Processing Record 19  of Set 7 | havoysund.
# Processing Record 20  of Set 7 | san isidro.
# Processing Record 21  of Set 7 | pagudpud.
# Processing Record 22  of Set 7 | japura.
# Processing Record 23  of Set 7 | altamont.
# Processing Record 24  of Set 7 | cabedelo.
# Processing Record 25  of Set 7 | batagay-alyta.
# Processing Record 26  of Set 7 | amberley.
# Processing Record 27  of Set 7 | kawana waters.
# City not found...skipping.
# Processing Record 28  of Set 7 | tornio.
# Processing Record 29  of Set 7 | ust-kamchatsk.
# City not found...skipping.
# Processing Record 30  of Set 7 | ahipara.
# Processing Record 31  of Set 7 | yulara.
# Processing Record 32  of Set 7 | pinega.
# Processing Record 33  of Set 7 | zhigalovo.
# Processing Record 34  of Set 7 | tsihombe.
# City not found...skipping.
# Processing Record 35  of Set 7 | craig.
# Processing Record 36  of Set 7 | aklavik.
# Processing Record 37  of Set 7 | iquique.
# Processing Record 38  of Set 7 | alappuzha.
# City not found...skipping.
# Processing Record 39  of Set 7 | saint anthony.
# Processing Record 40  of Set 7 | muisne.
# Processing Record 41  of Set 7 | schoneiche.
# Processing Record 42  of Set 7 | luanda.
# Processing Record 43  of Set 7 | warrnambool.
# Processing Record 44  of Set 7 | durango.
# Processing Record 45  of Set 7 | esperance.
# Processing Record 46  of Set 7 | bagn.
# Processing Record 47  of Set 7 | bama.
# Processing Record 48  of Set 7 | kangalassy.
# Processing Record 49  of Set 7 | oussouye.
# Processing Record 0  of Set 8 | estepona.
# Processing Record 1  of Set 8 | tucurui.
# Processing Record 2  of Set 8 | abnub.
# Processing Record 3  of Set 8 | lata.
# Processing Record 4  of Set 8 | le moule.
# Processing Record 5  of Set 8 | mehamn.
# Processing Record 6  of Set 8 | kutum.
# Processing Record 7  of Set 8 | varna.
# Processing Record 8  of Set 8 | zhanakorgan.
# Processing Record 9  of Set 8 | churapcha.
# Processing Record 10  of Set 8 | sur.
# Processing Record 11  of Set 8 | wuwei.
# Processing Record 12  of Set 8 | kilindoni.
# Processing Record 13  of Set 8 | huimilpan.
# Processing Record 14  of Set 8 | mergui.
# City not found...skipping.
# Processing Record 15  of Set 8 | kandrian.
# Processing Record 16  of Set 8 | kargil.
# Processing Record 17  of Set 8 | limbang.
# Processing Record 18  of Set 8 | usevya.
# City not found...skipping.
# Processing Record 19  of Set 8 | orlovskiy.
# Processing Record 20  of Set 8 | ambodifototra.
# City not found...skipping.
# Processing Record 21  of Set 8 | suluq.
# Processing Record 22  of Set 8 | geraldton.
# Processing Record 23  of Set 8 | nguiu.
# City not found...skipping.
# Processing Record 24  of Set 8 | shu.
# Processing Record 25  of Set 8 | greeley.
# Processing Record 26  of Set 8 | chubbuck.
# Processing Record 27  of Set 8 | nikki.
# Processing Record 28  of Set 8 | guerrero negro.
# Processing Record 29  of Set 8 | xingcheng.
# Processing Record 30  of Set 8 | kaoma.
# Processing Record 31  of Set 8 | dawson creek.
# Processing Record 32  of Set 8 | camacha.
# Processing Record 33  of Set 8 | canico.
# Processing Record 34  of Set 8 | togur.
# Processing Record 35  of Set 8 | sierra vista.
# Processing Record 36  of Set 8 | labutta.
# City not found...skipping.
# Processing Record 37  of Set 8 | novichikha.
# Processing Record 38  of Set 8 | mangrol.
# Processing Record 39  of Set 8 | burnie.
# Processing Record 40  of Set 8 | klyuchi.
# Processing Record 41  of Set 8 | berdigestyakh.
# Processing Record 42  of Set 8 | ponta do sol.
# Processing Record 43  of Set 8 | eugene.
# Processing Record 44  of Set 8 | omboue.
# Processing Record 45  of Set 8 | nanortalik.
# Processing Record 46  of Set 8 | tutoia.
# Processing Record 47  of Set 8 | bud.
# Processing Record 48  of Set 8 | vostok.
# Processing Record 49  of Set 8 | skalistyy.
# City not found...skipping.
# Processing Record 0  of Set 9 | meulaboh.
# Processing Record 1  of Set 9 | kruisfontein.
# Processing Record 2  of Set 9 | haibowan.
# City not found...skipping.
# Processing Record 3  of Set 9 | tiznit.
# Processing Record 4  of Set 9 | benalla.
# Processing Record 5  of Set 9 | caravelas.
# Processing Record 6  of Set 9 | sirfa.
# City not found...skipping.
# Processing Record 7  of Set 9 | laguna.
# Processing Record 8  of Set 9 | huntingdon.
# Processing Record 9  of Set 9 | aquiraz.
# Processing Record 10  of Set 9 | pisco.
# Processing Record 11  of Set 9 | coquimbo.
# Processing Record 12  of Set 9 | yerofey pavlovich.
# Processing Record 13  of Set 9 | awjilah.
# Processing Record 14  of Set 9 | nadym.
# Processing Record 15  of Set 9 | mumford.
# Processing Record 16  of Set 9 | nowa sol.
# Processing Record 17  of Set 9 | ilo.
# Processing Record 18  of Set 9 | moses lake.
# Processing Record 19  of Set 9 | haines junction.
# Processing Record 20  of Set 9 | solok.
# Processing Record 21  of Set 9 | bukama.
# Processing Record 22  of Set 9 | rosario.
# Processing Record 23  of Set 9 | balkhash.
# Processing Record 24  of Set 9 | frontignan.
# Processing Record 25  of Set 9 | chapada dos guimaraes.
# Processing Record 26  of Set 9 | vilhena.
# Processing Record 27  of Set 9 | marianske lazne.
# Processing Record 28  of Set 9 | high level.
# Processing Record 29  of Set 9 | xuanhua.
# Processing Record 30  of Set 9 | petropavlovsk-kamchatskiy.
# Processing Record 31  of Set 9 | mao.
# Processing Record 32  of Set 9 | miri.
# Processing Record 33  of Set 9 | portobelo.
# Processing Record 34  of Set 9 | dongsheng.
# Processing Record 35  of Set 9 | tocopilla.
# Processing Record 36  of Set 9 | magdagachi.
# Processing Record 37  of Set 9 | shebalino.
# Processing Record 38  of Set 9 | pattoki.
# Processing Record 39  of Set 9 | honiara.
# Processing Record 40  of Set 9 | verkhnevilyuysk.
# Processing Record 41  of Set 9 | panzhihua.
# Processing Record 42  of Set 9 | saint-michel-des-saints.
# Processing Record 43  of Set 9 | solnechnyy.
# Processing Record 44  of Set 9 | bulnes.
# Processing Record 45  of Set 9 | terenos.
# Processing Record 46  of Set 9 | labuhan.
# Processing Record 47  of Set 9 | mount gambier.
# Processing Record 48  of Set 9 | seoul.
# Processing Record 49  of Set 9 | ironton.
# Processing Record 0  of Set 10 | haradok.
# Processing Record 1  of Set 10 | tidore.
# City not found...skipping.
# Processing Record 2  of Set 10 | bagan.
# Processing Record 3  of Set 10 | warqla.
# City not found...skipping.
# Processing Record 4  of Set 10 | arman.
# Processing Record 5  of Set 10 | monrovia.
# Processing Record 6  of Set 10 | san cristobal.
# Processing Record 7  of Set 10 | northam.
# Processing Record 8  of Set 10 | khed brahma.
# Processing Record 9  of Set 10 | bengkulu.
# City not found...skipping.
# Processing Record 10  of Set 10 | vangaindrano.
# Processing Record 11  of Set 10 | chalchihuites.
# Processing Record 12  of Set 10 | goroka.
# Processing Record 13  of Set 10 | chicomuselo.
# Processing Record 14  of Set 10 | fortuna.
# Processing Record 15  of Set 10 | sinnamary.
# Processing Record 16  of Set 10 | menongue.
# Processing Record 17  of Set 10 | port macquarie.
# Processing Record 18  of Set 10 | wajima.
# Processing Record 19  of Set 10 | brigantine.
# Processing Record 20  of Set 10 | pennsville.
# Processing Record 21  of Set 10 | sainte-thecle.
# Processing Record 22  of Set 10 | acapulco.
# Processing Record 23  of Set 10 | cockburn harbour.
# City not found...skipping.
# Processing Record 24  of Set 10 | payo.
# Processing Record 25  of Set 10 | yaan.
# Processing Record 26  of Set 10 | puerto leguizamo.
# Processing Record 27  of Set 10 | bilma.
# Processing Record 28  of Set 10 | belmonte.
# Processing Record 29  of Set 10 | jumla.
# Processing Record 30  of Set 10 | camacari.
# Processing Record 31  of Set 10 | sao jose da coroa grande.
# Processing Record 32  of Set 10 | mildura.
# Processing Record 33  of Set 10 | rochegda.
# Processing Record 34  of Set 10 | port-gentil.
# Processing Record 35  of Set 10 | kasongo-lunda.
# Processing Record 36  of Set 10 | vestmannaeyjar.
# Processing Record 37  of Set 10 | mandalgovi.
# Processing Record 38  of Set 10 | blackmans.
# City not found...skipping.
# Processing Record 39  of Set 10 | great bend.
# Processing Record 40  of Set 10 | tura.
# Processing Record 41  of Set 10 | sola.
# Processing Record 42  of Set 10 | ostrovnoy.
# Processing Record 43  of Set 10 | valdivia.
# Processing Record 44  of Set 10 | sakakah.
# City not found...skipping.
# Processing Record 45  of Set 10 | kloulklubed.
# Processing Record 46  of Set 10 | dawson.
# Processing Record 47  of Set 10 | iernut.
# Processing Record 48  of Set 10 | gazojak.
# Processing Record 49  of Set 10 | vila do maio.
# Processing Record 0  of Set 11 | rocha.
# Processing Record 1  of Set 11 | djenne.
# Processing Record 2  of Set 11 | hirara.
# Processing Record 3  of Set 11 | bratsk.
# Processing Record 4  of Set 11 | quatre cocos.
# Processing Record 5  of Set 11 | moron.
# Processing Record 6  of Set 11 | ohara.
# Processing Record 7  of Set 11 | viligili.
# City not found...skipping.
# Processing Record 8  of Set 11 | karpathos.
# Processing Record 9  of Set 11 | iskateley.
# Processing Record 10  of Set 11 | kot putli.
# City not found...skipping.
# Processing Record 11  of Set 11 | salekhard.
# Processing Record 12  of Set 11 | bantou.
# Processing Record 13  of Set 11 | poduri.
# Processing Record 14  of Set 11 | ahuimanu.
# Processing Record 15  of Set 11 | aden.
# Processing Record 16  of Set 11 | christchurch.
# Processing Record 17  of Set 11 | umm kaddadah.
# Processing Record 18  of Set 11 | kavkazskiy.
# Processing Record 19  of Set 11 | gubkinskiy.
# Processing Record 20  of Set 11 | joniskis.
# Processing Record 21  of Set 11 | belgrade.
# Processing Record 22  of Set 11 | larap.
# Processing Record 23  of Set 11 | borogontsy.
# Processing Record 24  of Set 11 | lompoc.
# Processing Record 25  of Set 11 | havre-saint-pierre.
# Processing Record 26  of Set 11 | inta.
# Processing Record 27  of Set 11 | port hedland.
# Processing Record 28  of Set 11 | ayan.
# Processing Record 29  of Set 11 | esmeraldas.
# Processing Record 30  of Set 11 | saldanha.
# Processing Record 31  of Set 11 | zaoyang.
# Processing Record 32  of Set 11 | zyukayka.
# Processing Record 33  of Set 11 | elizabethtown.
# Processing Record 34  of Set 11 | macia.
# Processing Record 35  of Set 11 | sioux lookout.
# Processing Record 36  of Set 11 | apatzingan.
# City not found...skipping.
# Processing Record 37  of Set 11 | okha.
# Processing Record 38  of Set 11 | bemidji.
# Processing Record 39  of Set 11 | mayo.
# Processing Record 40  of Set 11 | eirunepe.
# Processing Record 41  of Set 11 | zaozerne.
# Processing Record 42  of Set 11 | cayenne.
# Processing Record 43  of Set 11 | bielsk podlaski.
# Processing Record 44  of Set 11 | taoudenni.
# Processing Record 45  of Set 11 | galesong.
# Processing Record 46  of Set 11 | enshi.
# Processing Record 47  of Set 11 | la brea.
# Processing Record 48  of Set 11 | monte patria.
# Processing Record 49  of Set 11 | mogadishu.
# Processing Record 0  of Set 12 | raymond terrace.
# Processing Record 1  of Set 12 | banjarmasin.
# Processing Record 2  of Set 12 | beringovskiy.
# Processing Record 3  of Set 12 | vytegra.
# Processing Record 4  of Set 12 | gidole.
# Processing Record 5  of Set 12 | cheremnoye.
# Processing Record 6  of Set 12 | praia.
# Processing Record 7  of Set 12 | honningsvag.
# Processing Record 8  of Set 12 | gloversville.
# Processing Record 9  of Set 12 | belogorsk.
# Processing Record 10  of Set 12 | caraballeda.
# Processing Record 11  of Set 12 | sheksna.
# Processing Record 12  of Set 12 | turkan.
# Processing Record 13  of Set 12 | rongcheng.
# Processing Record 14  of Set 12 | tremedal.
# Processing Record 15  of Set 12 | busok.
# Processing Record 16  of Set 12 | juneau.
# Processing Record 17  of Set 12 | kizukuri.
# Processing Record 18  of Set 12 | sobolevo.
# Processing Record 19  of Set 12 | holguin.
# Processing Record 20  of Set 12 | katangli.
# Processing Record 21  of Set 12 | takoradi.
# Processing Record 22  of Set 12 | bullingen.
# City not found...skipping.
# Processing Record 23  of Set 12 | izumo.
# Processing Record 24  of Set 12 | isla vista.
# Processing Record 25  of Set 12 | arvi.
# Processing Record 26  of Set 12 | veraval.
# Processing Record 27  of Set 12 | eunice.
# Processing Record 28  of Set 12 | sokolo.
# Processing Record 29  of Set 12 | yusva.
# City not found...skipping.
# Processing Record 30  of Set 12 | manadhoo.
# Processing Record 31  of Set 12 | okhotsk.
# Processing Record 32  of Set 12 | umm lajj.
# Processing Record 33  of Set 12 | saint-francois.
# Processing Record 34  of Set 12 | puerto madryn.
# Processing Record 35  of Set 12 | tezu.
# Processing Record 36  of Set 12 | kidal.
# Processing Record 37  of Set 12 | paamiut.
# Processing Record 38  of Set 12 | ko samui.
# Processing Record 39  of Set 12 | hervey bay.
# Processing Record 40  of Set 12 | whyalla.
# Processing Record 41  of Set 12 | atasu.
# Processing Record 42  of Set 12 | fort morgan.
# Processing Record 43  of Set 12 | gornyak.
# Processing Record 44  of Set 12 | raga.
# City not found...skipping.
# Processing Record 45  of Set 12 | kashi.
# City not found...skipping.
# Processing Record 46  of Set 12 | rio gallegos.
# Processing Record 47  of Set 12 | lolua.
# City not found...skipping.
# Processing Record 48  of Set 12 | cachoeiras de macacu.
# Processing Record 49  of Set 12 | nakhon nayok.
# Processing Record 0  of Set 13 | tazovskiy.
# Processing Record 1  of Set 13 | ayorou.
# Processing Record 2  of Set 13 | altamira.
# Processing Record 3  of Set 13 | port-cartier.
# Processing Record 4  of Set 13 | akyab.
# City not found...skipping.
# Processing Record 5  of Set 13 | roald.
# Processing Record 6  of Set 13 | flinders.
# Processing Record 7  of Set 13 | yirol.
# City not found...skipping.
# Processing Record 8  of Set 13 | korla.
# City not found...skipping.
# Processing Record 9  of Set 13 | arua.
# Processing Record 10  of Set 13 | nizhniy odes.
# Processing Record 11  of Set 13 | fort saint john.
# City not found...skipping.
# Processing Record 12  of Set 13 | barinitas.
# Processing Record 13  of Set 13 | salinopolis.
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather= pd.DataFrame(weather_df)
weather.count()
# Out:
# City          614
# Cloudiness    614
# Country       614
# Date          614
# Humidity      614
# Latitude      614
# Longitude     614
# Max Temp      614
# Wind Speed    614
# dtype: int64

# %%
#Displaying Dataframe
weather= pd.DataFrame(weather_df)
weather.head()
# Out:
#         City Cloudiness Country        Date Humidity Latitude Longitude  \
# 0    monster         90      NL  1569457585       87    52.03      4.17
# 1      kapaa         20      US  1569457585       83    22.08   -159.32
# 2  tilichiki        100      RU  1569457585       83    60.47     166.1
# 3  upernavik         99      GL  1569457586       66    72.79    -56.15
# 4      conde         17      BR  1569457586       97   -11.81    -37.61
#
#   Max Temp Wind Speed
# 0   289.26        6.2
# 1   302.15        2.6
# 2  281.895       3.49
# 3  273.945       4.23
# 4  293.634       1.34

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
weather.replace("", np.nan, inplace = True)
weather = weather_df.dropna()
weather.head()
print(f"There are {len(weather)} cities included in the weather analyses.")
weather.to_csv("weather_output.csv", index=False, encoding='utf-8')
weather.dropna()
weather.dtypes
weather.convert_objects(convert_numeric=True).dtypes
# Out:
# There are 540 cities included in the weather analyses.
# C:\Users\Acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# City           object
# Cloudiness      int64
# Country        object
# Date            int64
# Humidity        int64
# Latitude      float64
# Longitude     float64
# Max Temp      float64
# Wind Speed    float64
# dtype: object

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather["Latitude"], weather["Max Temp"],edgecolors="black", c="blue")
plt.title("City Latitude vs. Max Temperature (09/24/19)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid (linestyle="-")
plt.savefig("City Latitude vs. Max Temperature.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather["Latitude"], weather["Humidity"],edgecolors="black", c="blue")
plt.title("City Latitude vs. Humidity(09/24/2019)")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid (linestyle="-")
plt.savefig("City Latitude vs. Humidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather["Latitude"], weather["Cloudiness"],edgecolors="black", c="blue")
plt.title("City Latitude vs. Cloudiness (09/24/19)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.grid (linestyle="-")
plt.savefig("City Latitude vs. Cloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather["Latitude"], weather["Wind Speed"],edgecolors="black", c="blue")
plt.title("City Latitude vs. Wind Speed (09/24/19)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid (linestyle="-")
plt.savefig("City Latitude vs. Wind Speed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.8151657406810827

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.760263355051646

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.10358336015746494

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.14689473425583055

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.08733547918934018

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.21881426893991618

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.1071382774388479

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.322483077139538
